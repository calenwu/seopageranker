# %%
import html
import json
import os
import random
import requests

from bs4 import BeautifulSoup
from datetime import datetime, timedelta

from dotenv import load_dotenv

from openai import OpenAI
from openai.types.chat import ChatCompletion

from typing import List, Tuple
from slugify import slugify

# %%
load_dotenv()
OPENAI_SECRET_KEY = os.getenv('OPENAI_SECRET_KEY')

# %%
class OpenAi():
	def __init__(self, api_key):
		self.client = OpenAI(api_key=api_key)
	
	def generate_title(self, url: str) -> str:
		response = self.client.chat.completions.create(
			model='gpt-3.5-turbo',
			max_tokens=4096,
			messages=[
				{'role': 'system', 'content': 'You are an SEO expert. Given a url your task is it to find a title for a blog page that will rank well in search engines. json format: {"title": "title"}'},
				{'role': 'user', 'content': 'https://coinflip.tech/blog/unraveling-the-fed-market-news-bitcoin-moves'}
			],
			response_format={'type': 'json_object'},
		)
		json_response = response.choices[0].message.content.strip()
		return json.loads(json_response)['title']

	def generate_sub_titles(self, title: str) -> List[str]:
		response = self.client.chat.completions.create(
			model='gpt-3.5-turbo',
			max_tokens=4096,
			messages=[
				{'role': 'system', 'content': 'You are an SEO expert and write blog posts which are SEO optimized. A title for a blog post, generate 6 section subtitles. json format: {"titles": ["title1", "title2", "title3", "title4", "title5", "title6" ]}'},
				{'role': 'user', 'content': title}
			],
			response_format={'type': 'json_object'},
		)

		json_response = response.choices[0].message.content.strip()
		return json.loads(json_response)['titles']
	
	def relevant_sitemap(self, sitemap_xml: str) -> bool:
		response = self.client.chat.completions.create(
			model='gpt-3.5-turbo',
			max_tokens=128,
			messages=[
				{'role': 'system', 'content': 'You are an SEO expert. Given a links of a sitemap you have to say True or False to weather the pages on sitemap as a whole is relevant for page seo. respond with "True" for relevant and "False" for irrelevant. json format: {"answer": "True"}'},
				{'role': 'user', 'content': sitemap_xml}
			],
			response_format={'type': 'json_object'},
		)
		json_response = response.choices[0].message.content.strip()
		return json.loads(json_response)['answer'] == 'True'
	
	def genearte_first_section(self, title: str, sub_title: str) -> str:
		response = self.client.chat.completions.create(
			model='gpt-4-0125-preview',
			max_tokens=4096,
			messages=[
				{'role': 'system', 'content': 'You are an SEO expert. Your task is it to write a section for a blog. You will be given the title and sub titles of each section and your task is it to write the introduction, that is the first section which introduces the article. Return it in html format. The article must be SEO friendly and do well for keywords. Do not create a div wrapper which wraps the whole article. Json format: {"article": "article in html format"}'},
				{'role': 'user', 'content': f'title: {title}, sub_titles: {sub_title}'}
			],
			response_format={'type': 'json_object'},
		)
		json_response = response.choices[0].message.content.strip()
		return json.loads(json_response)['article']
	
	def generate_section(self, title: str, sub_title: str) -> str:
		response = self.client.chat.completions.create(
			model='gpt-4-0125-preview',
			max_tokens=4096,
			messages=[
				{'role': 'system', 'content': 'You are an SEO expert. Your task is it to write a section for a blog, you are only writing a section of a blog, not the whole blog. Therefore do not create a summary or conclusion in the end if you do I will die. You will be given the title of the whole blog and the title of the section. The section you write should focus on the sub title without summarizing or concluding the overall argument. Never write a conclusion. Return the section in html format. It must be 600 to 700 words. The article must be SEO friendly and do well for keywords. Do not create a div wrapper which wraps the whole article. Json format: {"article": "article in html format"}'},
				{'role': 'user', 'content': f'title: {title}, sub_title: {sub_title}'}
			],
			response_format={'type': 'json_object'},
		)
		json_response = response.choices[0].message.content.strip()
		return json.loads(json_response)['article']
	
	def generate_conclusion(self, article: str) -> str:
		response = self.client.chat.completions.create(
			model='gpt-4-0125-preview',
			max_tokens=4096,
			messages=[
				{'role': 'system', 'content': 'You are an SEO expert. Your task is it to write a conclusion given the article. Return the section in html format. It must be 600 to 700 words. The article must be SEO friendly and do well for keywords. Do not create a div wrapper which wraps the whole article. Json format: {"article": "article in html format"}'},
				{'role': 'user', 'content': f'Article: {article}'}
			],
			response_format={'type': 'json_object'},
		)
		json_response = response.choices[0].message.content.strip()
		return json.loads(json_response)['article']

# %%
openai = OpenAi(os.getenv('OPENAI_SECRET_KEY'))

# %%
sitemaps_to_check = ['https://coinflip.tech/sitemap.xml']
articles = []

# %%
def sitemap_index(url: str) -> Tuple[bool, List[str]]:
	"""
	Checks if the sitemap is a sitemap index or a sitemap
	returns True if it is a sitemap index
	"""
	response = requests.get(url)
	soup = BeautifulSoup(response.content, 'xml')
	if soup.find('sitemapindex'):
		return (True, [loc.text for loc in soup.find_all('loc')])
	elif soup.find('urlset'):
		locs = [loc.text for loc in soup.find_all('loc')]
		return (False, locs if openai.relevant_sitemap(f"[{', '.join(locs)}]") else [])
	else:
		raise Exception('Invalid sitemap')

# %%
while sitemaps_to_check:
	url = sitemaps_to_check.pop()
	is_sitemap_index, urls = sitemap_index(url)
	if is_sitemap_index:
		sitemaps_to_check.extend(urls)
	else:
		articles.extend(urls)

# %%
articles
# Out:
# ['https://coinflip.tech/en-CA',
#  'https://coinflip.tech/pt-BR',
#  'https://coinflip.tech/es-PA',
#  'https://coinflip.tech/en-ZA',
#  'https://coinflip.tech/en-AU',
#  'https://coinflip.tech/en-NZ',
#  'https://coinflip.tech/blog/unraveling-the-fed-market-news-bitcoin-moves',
#  'https://coinflip.tech/blog/correlations-between-bitcoin-and-the-nasdaq',
#  'https://coinflip.tech/blog/coinflip-preferred-q1-recap',
#  'https://coinflip.tech/blog/bitcoin-halving',
#  'https://coinflip.tech/blog/the-ebb-and-flow-of-bitcoin-in-turbulent-economic-times',
#  'https://coinflip.tech/blog/cryptocurrency-explained-stellar',
#  'https://coinflip.tech/blog/cryptocurrency-explained-binance',
#  'https://coinflip.tech/blog/cryptocurrency-explained-what-is-pax-gold',
#  'https://coinflip.tech/blog/beware-the-hidden-fees',
#  'https://coinflip.tech/blog/when-is-bitcoin-pizza-day-and-why-do-crypto-fans-care',
#  'https://coinflip.tech/blog/diversifying-your-portfolio-with-crypto-and-diversifying-your-crypto',
#  'https://coinflip.tech/blog/cryptocurrency-explained-ethereum',
#  'https://coinflip.tech/blog/july-2021-updates',
#  'https://coinflip.tech/blog/crypto-is-turning-to-self-custodial-wallets-and-services',
#  'https://coinflip.tech/blog/coinflip-rolling-out-olliv',
#  'https://coinflip.tech/blog/cryptocurrency-explained-dogecoin',
#  'https://coinflip.tech/blog/is-now-the-time-to-buy-the-dip',
#  'https://coinflip.tech/blog/6-reasons-to-consider-buying-and-selling-crypto-with-CoinFlip-Preferred',
#  'https://coinflip.tech/blog/how-does-the-taproot-update-impact-you',
#  'https://coinflip.tech/blog/what-are-stablecoins-and-why-do-people-use-them',
#  'https://coinflip.tech/blog/cryptocurrency-explained-crypto-wallet',
#  'https://coinflip.tech/blog/what-is-defi',
#  'https://coinflip.tech/blog/crypto-current-events-btc-bullishness-ltcs-birthday-bidens-rumors',
#  'https://coinflip.tech/blog/ethereum-shanghai-upgrade-what-you-need-to-know',
#  'https://coinflip.tech/blog/cryptocurrency-explained-chainlink',
#  'https://coinflip.tech/blog/cryptocurrency-explained-how-bitcoin-works',
#  'https://coinflip.tech/blog/how-does-a-bitcoin-atm-work',
#  'https://coinflip.tech/blog/cryptocurrency-explained-xrp',
#  'https://coinflip.tech/blog/buy-physical-gold-with-cryptocurrency',
#  'https://coinflip.tech/blog/coinflip-announces-bitcoin-atms-in-canada-as-part-of-international-expansion',
#  'https://coinflip.tech/blog/cryptocurrency-explained-litecoin',
#  'https://coinflip.tech/blog/5-worst-cryptocurrency-investing-mistakes-to-avoid',
#  'https://coinflip.tech/blog/btc-price-hits-6-week-high-apple-google-scrutiny-crypto-apps',
#  'https://coinflip.tech/blog/vauld-suspends-activity-meta-axes-novi',
#  'https://coinflip.tech/blog/cryptocurrency-explained-a-beginners-guide-to-buying-crypto',
#  'https://coinflip.tech/blog/getting-started-with-crypto-CoinFlip-Preferred-q-and-a',
#  'https://coinflip.tech/blog/what-is-bitcoin-trading-and-how-does-it-work',
#  'https://coinflip.tech/blog/what-is-a-crypto-atm-and-how-does-it-work',
#  'https://coinflip.tech/blog/billions-new-crypto-users-blazing-fast-crypto-cars',
#  'https://coinflip.tech/blog/3-reasons-you-should-avoid-paypal-and-robinhood-when-buying-crypto',
#  'https://coinflip.tech/blog/giving-the-gift-of-crypto',
#  'https://coinflip.tech/blog/positive-news-percolating-crypto-world-june-27-2022',
#  'https://coinflip.tech/blog/cryptocurrency-explained-aave',
#  'https://coinflip.tech/blog/cryptocurrency-explained-dash',
#  'https://coinflip.tech/blog/glass-half-full-positive-takes-from-the-crypto-world',
#  'https://coinflip.tech/blog/what-is-over-the-counter-otc-crypto-trading-and-how-does-it-work',
#  'https://coinflip.tech/blog/why-emerging-economies-are-reeling-from-the-terra-stablecoin-crash',
#  'https://coinflip.tech/blog/cryptocurrency-overview-bitcoin-litecoin-ethereum',
#  'https://coinflip.tech/blog/what-is-web3-and-why-does-it-matter',
#  'https://coinflip.tech/blog/banking-struggles-blockchain-and-the-environment',
#  'https://coinflip.tech/blog/meet-the-coinflip-bitcoin-atm-team',
#  'https://coinflip.tech/blog/how-to-sell-crypto-at-a-bitcoin-atm',
#  'https://coinflip.tech/blog/cryptocurrency-explained-what-is-solana',
#  'https://coinflip.tech/blog/cryptocurrency-explained-what-is-cardano',
#  'https://coinflip.tech/blog/spotting-crypto-scams-and-avoiding-them',
#  'https://coinflip.tech/blog/buying-bitcoin-may-be-smarter-than-you-think-heres-why-buying-with-coinflip',
#  'https://coinflip.tech/blog/the-5-biggest-bitcoin-blunders-of-all-time',
#  'https://coinflip.tech/blog/whats-behind-ethereums-new-all-time-high',
#  'https://coinflip.tech/blog/women-in-crypto-6-influential-women-in-the-industry',
#  'https://coinflip.tech/blog/how-to-report-bitcoin-on-your-2020-taxes-or-coinflip-atm',
#  'https://coinflip.tech/blog/cryptocurrency-explained-how-to-spend-bitcoin',
#  'https://coinflip.tech/blog/can-blockchain-technology-improve-environmental-sustainability-coinflip',
#  'https://coinflip.tech/blog/how-is-bitcoin-regulated',
#  'https://coinflip.tech/blog/coinflip-welcomes-bnb-relisting',
#  'https://coinflip.tech/blog/bitcoin-buyers-see-steady-price-rebound-what-cryptocurrency-investors-should',
#  'https://coinflip.tech/blog/the-pros-and-cons-of-bitcoin-atms',
#  'https://coinflip.tech/blog/the-5-biggest-benefits-of-bitcoin',
#  'https://coinflip.tech/blog/bitcoin-a-solution-to-economic-uncertainty',
#  'https://coinflip.tech/blog/how-bitcoin-atms-helped-one-person-lift-themselves-out-of-homelessness',
#  'https://coinflip.tech/blog/the-pros-and-cons-of-spending-bitcoin',
#  'https://coinflip.tech/blog/may-2021-updates',
#  'https://coinflip.tech/blog/cryptocurrency-explained-what-is-an-nft',
#  'https://coinflip.tech/blog/coin-vs-token-whats-the-difference',
#  'https://coinflip.tech/blog/20-crypto-terms-you-need-to-know',
#  'https://coinflip.tech/blog/3-tips-for-entering-the-nft-market',
#  'https://coinflip.tech/blog/what-is-yield-farming',
#  'https://coinflip.tech/blog/can-blockchain-take-on-the-climate-crisis-regenerative-finance-says-yes',
#  'https://coinflip.tech/blog/a-look-into-canadas-crypto-forward-history',
#  'https://coinflip.tech/blog/november-2021-updates',
#  'https://coinflip.tech/blog/what-are-smart-contracts-and-why-are-they-important',
#  'https://coinflip.tech/blog/latest-regulation-affect-cryptocurrency',
#  'https://coinflip.tech/blog/ethereum-trust-daily-average-trading-overtakes-bitcoin-trust',
#  'https://coinflip.tech/blog/bitcoin-nft-controversy-fed-interest-rate-hike',
#  'https://coinflip.tech/blog/retail-crypto-payments-europe-pharmacies-gemini-dcg-public-feud',
#  'https://coinflip.tech/blog/gillibrand-and-lummis-introduce-wide-ranging-crypto-bill',
#  'https://coinflip.tech/blog/bank-woes-bring-fed-rate-hikes-under-scrutiny',
#  'https://coinflip.tech/blog/celsius-crypto-pay-back-plans-ai-investment-advice',
#  'https://coinflip.tech/blog/december-2021-updates',
#  'https://coinflip.tech/blog/ethereum-upgrade-dogecoin-twitter-fueled-pump',
#  'https://coinflip.tech/blog/top-10-celebrities-keen-on-crypto-in-2021',
#  'https://coinflip.tech/blog/celsius-bankruptcy-credit-cards-get-ready-for-crypto',
#  'https://coinflip.tech/blog/coinflip-reviews-the-trezor-one-hardware-wallet',
#  'https://coinflip.tech/blog/how-cryptocurrency-can-empower-migrant-workers',
#  'https://coinflip.tech/blog/how-to-buy-bitcoin-with-cash-safely-coinflip-bitcoin-atms',
#  'https://coinflip.tech/blog/what-gives-bitcoin-value-coinflip-explains',
#  'https://coinflip.tech/blog/how-to-use-a-bitcoin-atm-in-8-simple-steps',
#  'https://coinflip.tech/blog/the-convergence-of-ai-blockchain-and-the-token-economy',
#  'https://coinflip.tech/blog/what-silicon-valley-bank-collapse-means-for-crypto-market',
#  'https://coinflip.tech/blog/is-bitcoin-traceable',
#  'https://coinflip.tech/blog/nuclear-bitcoin-mine-eu-crypto-banking-regulation',
#  'https://coinflip.tech/blog/genesis-bankruptcy-spain-central-bank-digital-payments-2023',
#  'https://coinflip.tech/blog/inflation-cools-compliance-heats-up-crypto-winter',
#  'https://coinflip.tech/blog/crypto-curiosity-remains-strong-end-of-2022',
#  'https://coinflip.tech/blog/interest-rate-hikes-ftx-ceo-arrested-the-bahamas',
#  'https://coinflip.tech/blog/goldman-sachs-crypto-companies-sale-ipod-designer-crypto-wallet',
#  'https://coinflip.tech/blog/the-5-biggest-crypto-stories-of-2022',
#  'https://coinflip.tech/blog/november-2022-jobs-report-markets-ftx-ceo-media-tour',
#  'https://coinflip.tech/blog/crypto-lender-buys-stake-in-bank-swift-builds-cross-chain-protocol',
#  'https://coinflip.tech/blog/new-york-crypto-mining-law-polygon-nft-magic-eden',
#  'https://coinflip.tech/blog/digital-dollar-trial-run-crypto-world-sorts-out-ftx-aftermath',
#  'https://coinflip.tech/blog/weekly-flip-thru-the-crypto-world-reels-from-ftx-fallout-october-inflation',
#  'https://coinflip.tech/blog/fed-interest-rate-hike-crypto-money-midterm-elections',
#  'https://coinflip.tech/blog/uk-new-crypto-friendly-prime-minister-reddit-nfts-rise',
#  'https://coinflip.tech/blog/weekly-flip-thru-walmart-bets-big-on-crypto-payments-and-mastercard-works-to',
#  'https://coinflip.tech/blog/are-bitcoin-atms-safe',
#  'https://coinflip.tech/blog/how-cryptocurrency-can-accelerate-financial-inclusion',
#  'https://coinflip.tech/blog/weekly-flip-thru-google-to-allow-crypto-payments-eu-lawmakers-make-progress',
#  'https://coinflip.tech/blog/kim-kardashian-settles-sec-charges-crypto-social-media-post',
#  'https://coinflip.tech/blog/crypto-markets-react-fed-rate-hike-sec-claims-ethereum-jurisdiction',
#  'https://coinflip.tech/blog/white-house-asks-crypto-miners-to-go-green-fbi-recovers-30-million-axie-infinity-hack',
#  'https://coinflip.tech/blog/biden-admin-crypto-regulation-framework-crypto-bank-US-2023',
#  'https://coinflip.tech/blog/dao-crypto-reshape-campaign-fundraising',
#  'https://coinflip.tech/blog/what-is-a-crypto-bridge',
#  'https://coinflip.tech/blog/new-global-crypto-adoption-stats-move-to-earn-apps-pay-to-exercise',
#  'https://coinflip.tech/blog/crypto-crime-fell-early-2022-charles-schwab-offers-investors-exposure-crytpo-companies',
#  'https://coinflip.tech/blog/ethereum-merge-on-track-bitcoin-atms-pass-39k-globally',
#  'https://coinflip.tech/blog/what-is-cryptocurrency',
#  'https://coinflip.tech/blog/explaining-cryptocurrency-and-blockchain-basics-with-coinflip-founders',
#  'https://coinflip.tech/blog/retailers-eyeing-crypto-payments-bitcoin-atms-return-to-japan',
#  'https://coinflip.tech/blog/who-accepts-bitcoin-as-payment-in-2022',
#  'https://coinflip.tech/blog/ethereum-merge-what-you-need-to-know',
#  'https://coinflip.tech/blog/bitcoin-price-rallies-30-day-high-celsius-bitcoin-mining-payback-plan',
#  'https://coinflip.tech/blog/why-should-i-install-a-bitcoin-atm-in-my-business',
#  'https://coinflip.tech/blog/jp-morgan-execs-jump-to-crypto-firms-ethereum-merge-moves-closer',
#  'https://coinflip.tech/blog/the-benefits-of-bitcoin',
#  'https://coinflip.tech/blog/cryptocurrency-explained-gas-fees-faq',
#  'https://coinflip.tech/blog/bitcoin-as-legal-tender-update-on-el-salvador',
#  'https://coinflip.tech/blog/why-crypto-isnt-a-regulatory-wild-west',
#  'https://coinflip.tech/blog/the-biggest-moments-in-crypto-from-2021',
#  'https://coinflip.tech/blog/how-cryptocurrency-can-build-universal-financial-inclusion',
#  'https://coinflip.tech/blog/el-salvador-crypto-adoption-with-ben-weiss-flip-thru',
#  'https://coinflip.tech/blog/whats-is-a-bitcoin-atm-where-can-i-buy-bitcoin-in-the-usa',
#  'https://coinflip.tech/blog/how-inflation-worsens-economic-inequality-and-how-bitcoin-can-help',
#  'https://coinflip.tech/blog/bitcoin-and-sustainability-coinflip-celebrates-earth-day',
#  'https://coinflip.tech/blog/can-bitcoin-be-hacked',
#  'https://coinflip.tech/blog/5-common-crypto-scams-and-tips-to-avoid-them',
#  'https://coinflip.tech/blog/6-reasons-why-you-should-use-a-bitcoin-atm',
#  'https://coinflip.tech/blog/who-is-satoshi-nakamoto',
#  'https://coinflip.tech/blog/litecoin-vs-ethereum-which-is-better',
#  'https://coinflip.tech/blog/location-spotlight-beneath-the-surface-tattoo-las-vegas-nv',
#  'https://coinflip.tech/blog/vietnam-is-the-highest-ranking-country-for-cryptocurrency-adoption',
#  'https://coinflip.tech/blog/get-to-know-the-coins-and-tokens',
#  'https://coinflip.tech/blog/what-is-a-crypto-wallet',
#  'https://coinflip.tech/blog/10-tips-to-improve-your-financial-literacy',
#  'https://coinflip.tech/blog/how-to-withdraw-from-a-bitcoin-atm',
#  'https://coinflip.tech/blog/cryptocurrency-explained-usd-coin',
#  'https://coinflip.tech/blog/what-is-a-crypto-airdrop',
#  'https://coinflip.tech/blog/are-nfts-changing-the-way-people-think-about-games',
#  'https://coinflip.tech/blog/november-december-newsletter',
#  'https://coinflip.tech/blog/coinflip-customer-service',
#  'https://coinflip.tech/blog/how-cryptocurrency-is-aiding-ukrainian-refugees',
#  'https://coinflip.tech/blog/why-daos-might-be-the-next-big-thing',
#  'https://coinflip.tech/blog/how-the-international-crypto-community-can-donate-to-ukraine',
#  'https://coinflip.tech/blog/how-to-use-a-cryptocurrency-atm',
#  'https://coinflip.tech/blog/crypto-questions-how-do-i-invest-in-cryptocurrency',
#  'https://coinflip.tech/blog/why-did-nfts-turn-the-art-world-upside-down-in-2021',
#  'https://coinflip.tech/blog/how-bitcoin-got-started',
#  'https://coinflip.tech/blog/how-cryptocurrency-can-accelerate-humanitarian-aid-delivery',
#  'https://coinflip.tech/blog/give-the-gift-of-bitcoin-this-mothers-day',
#  'https://coinflip.tech/blog/flip-thru-bitcoin-spring-cleaning',
#  'https://coinflip.tech/blog/would-you-get-paid-in-bitcoin',
#  'https://coinflip.tech/blog/june-2021-updates',
#  'https://coinflip.tech/blog/how-to-stay-vigilant-against-social-media-scams',
#  'https://coinflip.tech/blog/so-flippin-easy-flip-thru',
#  'https://coinflip.tech/blog/bitcoin-bulls-buy-the-dip',
#  'https://coinflip.tech/blog/bitcoin-is-cool-but-have-you-tried-altcoins',
#  'https://coinflip.tech/blog/can-bitcoin-save-the-planet',
#  'https://coinflip.tech/blog/doge-skyrockets-to-first-place',
#  'https://coinflip.tech/blog/august-2021-updates',
#  'https://coinflip.tech/blog/september-2021-updates',
#  'https://coinflip.tech/blog/how-bitcoin-helped-further-nigerias-endsars-movement',
#  'https://coinflip.tech/blog/give-back-this-holiday-season-with-coinflip-and-a4cb',
#  'https://coinflip.tech/blog/crypto-history-proof-of-keys-day',
#  'https://coinflip.tech/blog/what-is-cryptocurrency-and-how-does-it-work',
#  'https://coinflip.tech/blog/how-to-host-a-bitcoin-atm',
#  'https://coinflip.tech/blog/october-2021-updates',
#  'https://coinflip.tech/blog/top-10-most-expensive-nfts-of-all-time',
#  'https://coinflip.tech/blog/what-is-proof-of-stake-and-how-does-it-differ-from-proof-of-work',
#  'https://coinflip.tech/blog/5-people-who-made-millions-off-bitcoin',
#  'https://coinflip.tech/blog/bitcoin-and-dating-dating-sites-romance-scams-and-last-minute-gifts',
#  'https://coinflip.tech/blog/recommendations-for-the-biden-administration-on-cryptocurrency',
#  'https://coinflip.tech/blog/bitcoin-mining-101',
#  'https://coinflip.tech/blog/how-bitcoin-can-benefit-black-communities-with-isaiah-jackson',
#  'https://coinflip.tech/blog/crypto-and-human-rights-what-i-love-about-bitcoin',
#  'https://coinflip.tech/blog/flip-thru-dogecoin',
#  'https://coinflip.tech/blog/cryptocurrency-explained-bitcoin-atm-locations',
#  'https://coinflip.tech/blog/crypto-companies-take-center-stage',
#  'https://coinflip.tech/blog/give-back-this-holiday-season-with-coinflip-and-accion',
#  'https://coinflip.tech/blog/taking-a-closer-look-at-the-energy-used-to-mine-bitcoin',
#  'https://coinflip.tech/blog/new-atm-locations-march-2021',
#  'https://coinflip.tech/blog/a-better-bitcoin-is-on-the-horizon',
#  'https://coinflip.tech/blog/coinflip-may-2020-updates',
#  'https://coinflip.tech/blog/whats-happening-in-washington',
#  'https://coinflip.tech/blog/crypto-made-convenient-with-coinflip-and-coinmap',
#  'https://coinflip.tech/blog/bitcoin-atm-the-safest-new-way-to-buy-cryptocurrency',
#  'https://coinflip.tech/blog/coinflip-rebrand',
#  'https://coinflip.tech/blog/coinflip-lists-usdc-across-network-of-over-720-atms',
#  'https://coinflip.tech/blog/is-your-state-crypto-friendly-here-are-the-best-bitcoin-states-in-the-u-s',
#  'https://coinflip.tech/blog/what-makes-cryptocurrency-volatile-here-are-the-reasons-why-crypto-prices',
#  'https://coinflip.tech/blog/where-can-i-use-cryptocurrency-and-where-can-i-buy-bitcoin-with-cash-near-me',
#  'https://coinflip.tech/blog/coinflips-comment-letter-regarding-fincens-proposed-rulemaking',
#  'https://coinflip.tech/blog/how-do-i-buy-bitcoin-with-cash-right-now',
#  'https://coinflip.tech/blog/a-low-risk-inflation-hedge-the-case-for-bitcoin-as-security-against',
#  'https://coinflip.tech/blog/millennials-are-ditching-banks-buying-bitcoin-for-retirement',
#  'https://coinflip.tech/blog/what-determines-the-price-of-cryptocurrency',
#  'https://coinflip.tech/support',
#  'https://coinflip.tech/pt-BR/support',
#  'https://coinflip.tech/es-PA/support',
#  'https://coinflip.tech/en-AU/support',
#  'https://coinflip.tech/en-NZ/support',
#  'https://coinflip.tech/host',
#  'https://coinflip.tech/pt-BR/host',
#  'https://coinflip.tech/es-PA/host',
#  'https://coinflip.tech/en-AU/host',
#  'https://coinflip.tech/en-NZ/host',
#  'https://coinflip.tech/otc',
#  'https://coinflip.tech/en-CA/otc',
#  'https://coinflip.tech/en-AU/otc',
#  'https://coinflip.tech/en-NZ/otc',
#  'https://coinflip.tech/bitcoin-atm',
#  'https://coinflip.tech/pt-BR/bitcoin-atm',
#  'https://coinflip.tech/es-PA/bitcoin-atm',
#  'https://coinflip.tech/en-AU/bitcoin-atm',
#  'https://coinflip.tech/en-NZ/bitcoin-atm',
#  'https://coinflip.tech/about',
#  'https://coinflip.tech/pt-BR/about',
#  'https://coinflip.tech/es-PA/about',
#  'https://coinflip.tech/en-AU/about',
#  'https://coinflip.tech/en-NZ/about',
#  'https://coinflip.tech/coming-soon',
#  'https://coinflip.tech/es-PA/coming-soon',
#  'https://coinflip.tech/otc-referral',
#  'https://coinflip.tech/pt-BR/otc-referral',
#  'https://coinflip.tech/es-PA/otc-referral',
#  'https://coinflip.tech/flip-the-coin',
#  'https://coinflip.tech/newsletter',
#  'https://coinflip.tech/how-to-use-crypto-wallet',
#  'https://coinflip.tech/pt-BR/how-to-use-crypto-wallet',
#  'https://coinflip.tech/es-PA/how-to-use-crypto-wallet',
#  'https://coinflip.tech/buy-bitcoin-online',
#  'https://coinflip.tech/pt-BR/buy-bitcoin-online',
#  'https://coinflip.tech/es-PA/buy-bitcoin-online',
#  'https://coinflip.tech/faq',
#  'https://coinflip.tech/pt-BR/faq',
#  'https://coinflip.tech/es-PA/faq',
#  'https://coinflip.tech/order-desk-webinar',
#  'https://coinflip.tech/pt-BR/order-desk-webinar',
#  'https://coinflip.tech/es-PA/order-desk-webinar',
#  'https://coinflip.tech/ubicaciones',
#  'https://coinflip.tech/terms/order-desk-terms-of-service',
#  'https://coinflip.tech/en-CA/terms/order-desk-terms-of-service',
#  'https://coinflip.tech/en-AU/terms/order-desk-terms-of-service',
#  'https://coinflip.tech/en-NZ/terms/order-desk-terms-of-service',
#  'https://coinflip.tech/terms/terms-of-service',
#  'https://coinflip.tech/en-CA/terms/terms-of-service',
#  'https://coinflip.tech/pt-BR/terms/terms-of-service',
#  'https://coinflip.tech/es-PA/terms/terms-of-service',
#  'https://coinflip.tech/en-AU/terms/terms-of-service',
#  'https://coinflip.tech/en-NZ/terms/terms-of-service',
#  'https://coinflip.tech/terms/privacy-policy',
#  'https://coinflip.tech/en-CA/terms/privacy-policy',
#  'https://coinflip.tech/pt-BR/terms/privacy-policy',
#  'https://coinflip.tech/es-PA/terms/privacy-policy',
#  'https://coinflip.tech/en-AU/terms/privacy-policy',
#  'https://coinflip.tech/en-NZ/terms/privacy-policy',
#  'https://coinflip.tech/terms/sms-messaging-terms-and-conditions',
#  'https://coinflip.tech/en-CA/terms/canada-sms-tos',
#  'https://coinflip.tech/terms/licenses',
#  'https://coinflip.tech/terms/financial-privacy-notice',
#  'https://coinflip.tech/terms/biometrics-privacy-policy',
#  'https://coinflip.tech/terms/responsible-marketing-policy']

# %%
def generate_article(url: str):
	title = openai.generate_title(url)
	sub_titles = openai.generate_sub_titles(title)
	description = openai.genearte_first_section(title, ', '.join(sub_titles))
	article = description
	description = BeautifulSoup(description, 'html.parser')
	description = description.p.text[:300]
	for sub_title in sub_titles:
		article += openai.generate_section(title, sub_title)
	article += openai.generate_conclusion(article)
	return {'title': title, 'slug': slugify(title), 'description': description, 'article': article}

# %%
article = generate_article('https://coinflip.tech/blog/bitcoin-halving')

# %%
def escape_html(s):
	return (
		s.replace("&", "&amp;")
		.replace("<", "&lt;")
		.replace(">", "&gt;")
		.replace("'", "&apos;")
		.replace('"', "&quot;")
	)

temp = article
print(temp)
soup = BeautifulSoup(temp['article'], 'html.parser')
first_h1 = soup.find('h1')
# If the first tag in the soup is a h1 tag, remove it
if soup.contents[0] == first_h1:
	first_h1.decompose()

for tag in soup():
	if 'class' in tag.attrs:
		del tag['class']
	if 'classname' in tag.attrs:
		del tag['classname']
	# Add 'className' attribute
	tag['className'] = 'blogContent'
	if tag.string is not None:
		tag.string = escape_html(tag.string.replace('’', "'"))
article['article'] = soup.prettify().replace("&amp;", "&").replace("&amp;", "&")
article['slug'] = slugify(article['title'])
# Out:
# {'title': 'Unraveling the Fed: Market News and Bitcoin Moves | CoinFlip Blog', 'slug': 'unraveling-the-fed-market-news-and-bitcoin-moves-coinflip-blog', 'description': "Welcome to our latest exploration on the CoinFlip Blog, where we delve into the intricate dance between the Federal Reserve's policies, market news, and the turbulent world of Bitcoin. In today's financial landscape, understanding the Federal Reserve's influence is more crucial than ever. Its decisi", 'article': '<h1 className="blogContent">\n Unraveling the Fed: Market News and Bitcoin Moves | CoinFlip Blog\n</h1>\n<p className="blogContent">\n Welcome to our latest exploration on the CoinFlip Blog, where we delve into the intricate dance between the Federal Reserve&amp;apos;s policies, market news, and the turbulent world of Bitcoin. In today&amp;apos;s financial landscape, understanding the Federal Reserve&amp;apos;s influence is more crucial than ever. Its decisions on interest rates and monetary policies send ripples across global markets, affecting everything from traditional stocks to the burgeoning realm of cryptocurrencies.\n</p>\n<p className="blogContent">\n In this comprehensive guide, we&amp;apos;ll start by introducing you to the foundational role of the Federal Reserve and its monumental influence on financial markets. We&amp;apos;ll dissect how the Fed&amp;apos;s actions impact market dynamics and explore the unique relationship between Bitcoin and market news. Following this, we&amp;apos;ll analyze how Bitcoin responds to announcements from the Federal Reserve and offer strategic insights for navigating Bitcoin trading in these volatile market conditions. By the end of this article, you&amp;apos;ll gain a deeper understanding of the intertwined worlds of central banking, financial markets, and cryptocurrency, along with key takeaways to inform your trading strategies. Whether you&amp;apos;re a seasoned trader or new to the cryptocurrency scene, this exploration will enhance your market analysis skills and help you make more informed decisions in the ever-evolving landscape of digital currencies.\n</p>\n<h2 className="blogContent">\n Introduction to the Federal Reserve\n</h2>\n<p className="blogContent">\n The Federal Reserve, commonly referred to as the Fed, holds a pivotal role in the United States economy, directly affecting financial markets, including the burgeoning realm of cryptocurrencies like Bitcoin. Understanding the Federal Reserve&amp;apos;s structure, objectives, and tools for influencing economic activity is crucial for anyone keen on navigating the financial landscape, particularly investors and enthusiasts in the cryptocurrency space. This section introduces the Fed&amp;apos;s foundational elements, setting the stage for deeper insights into how it interplays with market movements and digital currencies.\n</p>\n<p className="blogContent">\n Established in 1913, the Federal Reserve serves as the central bank of the United States, tasked with overseeing the nation&amp;apos;s monetary policy. Its primary goals include maximizing employment, stabilizing prices, and moderating long-term interest rates, a triad often referred to as its dual mandate. Through its policy decisions, the Fed directly influences the economy&amp;apos;s health, impacting everything from inflation rates to employment levels, and, indirectly, the valuation of assets like Bitcoin.\n</p>\n<p className="blogContent">\n The Fed operates independently of the government but in close cooperation with it, a balance designed to shield monetary policy from political pressures while ensuring accountability. It executes its mandate through a decentralized structure comprising the Board of Governors in Washington, D.C., and twelve regional Federal Reserve Banks scattered across the country. This decentralized system facilitates a broad perspective on economic conditions, crucial for making informed policy decisions.\n</p>\n<p className="blogContent">\n One of the Fed&amp;ap ...

# %%
def random_date(start_date=datetime(2021, 1, 1), end_date=datetime(2024, 4, 10)):
	random_date = start_date + (end_date - start_date) * random.random()
	# Format the date as a string in the format YYYY-MM-DD
	return random_date.strftime('%Y-%m-%d')

# %%
def create_nextjs_page(article: dict):
	return """
import {{ Metadata }} from 'next';

export const metadata: Metadata = {{
	metadataBase: new URL('https://mooncoinflip.com'),
	title: "{title}",
	description: "{description}",
	keywords: ['crypto', 'coinflip', 'casino', 'crypto casino', 'crypto coinflip', 'crypto gambling', 'gambling', 'gamble', 'crypto gamble', 'crypto gambling', 'crypto games', 'crypto game', 'crypto', 'bnb', 'binance smart chain', 'bsc', 'ethereum', 'double crypto'],
	icons: {{
		icon: 'https://mooncoinflip.com/imgs/icon.png',
		shortcut: 'https://mooncoinflip.com/imgs/logo_big.png',
		apple: 'https://mooncoinflip.com/imgs/icon.png',
	}},
	openGraph: {{
		title: "{title}",
		description: "{description}",
		url: 'https://mooncoinflip.com/blog/{slug}',
		siteName: "{title}",
		images: [
			{{
				url: 'https://mooncoinflip.com/blog/imgs/{slug}/header.webp',
				width: 1200,
				height: 800,
			}},
		],
		locale: 'en_US',
		type: 'website',
	}},
	twitter: {{
		card: 'summary_large_image',
		title: "{title}",
		description: "{description}",
		// siteId: '1467726470533754880',
		creator: '@mooncoinflipcom',
		// creatorId: '1467726470533754880',
		images: ['https://mooncoinflip.com/blog/imgs/{slug}/header.webp'],
	}},
	robots: {{
		index: true,
		follow: true,
		nocache: true,
		googleBot: {{
			index: true,
			follow: true,
		}},
	}},
}}

export default function Page() {{
	return <>
		<div className='flex justify-between flex-col md:flex-row'>
			<h1 className='mb-4'>
				{title_html}
			</h1>
			<p className='text-right mb-4'>
				Published: {date}
			</p>
		</div>
		<div>
			{article}
		</div>
	</>
}}
	""".format(
		title=article['title'],
		slug=article['slug'],
		description=article['description'], 
		title_html=html.escape(article['title']),
		date=random_date(),
		article=article['article']
	)

# %%
with open('output.tsx', 'w') as f:
	# Write the result to the file
	f.write(create_nextjs_page(article).strip().replace('’', "'"))
